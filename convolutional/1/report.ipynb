# %% [markdown]
# Изначально:
#
# Точность на тестовых данных: 0.0979
#
# Точность:
#
# на обучении: 0.099
#
# на валидации: 0.098
#
# Ошибка:
#
# на обучении: 4.157
#
# на валидации: 4.158
#
# Время обучения: 26 с.
#
# Задание 1:
#
# Точность на тестовых данных: 0.0979 (изменение: 0.00%)
#
# Точность:
#
# на обучении: 0.0987 (изменение: -0.30%)
#
# на валидации: 0.0980 (изменение: 0.00%)
#
# Ошибка:
#
# на обучении: 4.16 (изменение: +0.07%)
#
# на валидации: 4.16 (изменение: +0.05%)
#
# Время обучения: 31 с. (изменение: +19.23%)
#
# Задание 2:
#
# Точность на тестовых данных: 0.0979 (изменение: 0.00%)
#
# Точность:
#
# на обучении: 0.0987 (изменение: 0.00%)
#
# на валидации: 0.0986 (изменение: +0.61%)
#
# Ошибка:
#
# на обучении: 4.16 (изменение: 0.00%)
#
# на валидации: 4.16 (изменение: 0.00%)
#
# Время обучения: 31 с. (изменение: 0.00%)
#
# Задание 3:
#
# Точность на тестовых данных: 0.0979 (изменение: 0.00%)
#
# Точность:
#
# на обучении: 0.0988 (изменение: +0.10%)
#
# на валидации: 0.0980 (изменение: -0.61%)
#
# Ошибка:
#
# на обучении: 4.16 (изменение: 0.00%)
#
# на валидации: 4.16 (изменение: 0.00%)
#
# Время обучения: 36 с. (изменение: +16.13%)
#
# Задание 4:
#
# Точность на тестовых данных: 0.0979 (изменение: 0.00%)
#
# Средняя точность: 0.0987
#
# Время обучения: 151 с. (изменение: +319.44%)
#
# Задание 5:
#
# Точность на тестовых данных: 0.0979 (изменение: 0.00%)
#
# Средняя точность: 0.0987 (изменение: 0.00%)
#
# Время обучения: 153 с. (изменение: +1.32%)
#
# Лучшее/Худшее:
#
# Лучшая точность: 0.0988 на обучении (Задание 3).
#
# Худшая точность: 0.0979 на тестовых данных (все этапы).
#
# Максимальное время обучения: 153 с. (Задание 5).
