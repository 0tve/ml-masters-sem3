# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28, 1) (60000,) (10000, 28, 28, 1) (10000,)

# %%
model = models.Sequential()

# %%
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
# Out:
# c:\MyFolder\Projects\University\ml-masters-sem3\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# %%
model.add(layers.Conv2D(128, (3, 3), activation='relu')) # Дополнительный сверточный слой

# %%
model.add(layers.Flatten())

# %%
model.add(layers.Dense(128, activation='relu'))  # Дополнительный полносвязный слой

# %%
model.add(layers.Dense(64, activation='relu'))

# %%
# model.add(layers.Dense(10, activation='softmax')) # Выходной слой

# %%
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1032 - loss: 3.8199 - val_accuracy: 0.0974 - val_loss: 3.6605
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0973 - loss: 4.0408 - val_accuracy: 0.0980 - val_loss: 6.0397
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0967 - loss: 6.0689 - val_accuracy: 0.0980 - val_loss: 6.0397
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0976 - loss: 6.0009 - val_accuracy: 0.0980 - val_loss: 6.0397
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0979 - loss: 6.0443 - val_accuracy: 0.0980 - val_loss: 6.0397

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Точность на тестовых данных: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0924 - loss: 6.1120
# Точность на тестовых данных: 0.09799999743700027

# %%
plt.plot(history.history['accuracy'], label='Точность на обучении')
plt.plot(history.history['val_accuracy'], label='Точность на валидации')
plt.title('Точность модели')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Ошибка на обучении')
plt.plot(history.history['val_loss'], label='Ошибка на валидации')
plt.title('Ошибка модели')
plt.xlabel('Эпоха')
plt.ylabel('Ошибка')
plt.legend()
plt.show()
