# %% [markdown]
# Изначально:
#
# Точность на тестовых данных: 0.7103
#
# Точность:
#
# на обучении: 0.78
#
# на валидации: 0.69
#
# Ошибка:
#
# на обучении: 0.65
#
# на валидации: 0.95
#
# Время обучения: 52 с.
#
# Задание 1:
#
# Точность на тестовых данных: 0.7236 (изменение: +1.87%)
#
# Точность:
#
# на обучении: 0.85 (изменение: +8.97%)
#
# на валидации: 0.70 (изменение: +1.45%)
#
# Ошибка:
#
# на обучении: 0.50 (изменение: -23.08%)
#
# на валидации: 0.90 (изменение: -5.26%)
#
# Время обучения: 223 с. (изменение: +328.85%)
#
# Задание 2:
#
# Точность на тестовых данных: 0.6269 (изменение: -13.37%)
#
# Точность:
#
# на обучении: 0.65 (изменение: -23.53%)
#
# на валидации: 0.60 (изменение: -14.29%)
#
# Ошибка:
#
# на обучении: 1.0 (изменение: +100.00%)
#
# на валидации: 1.1 (изменение: +22.22%)
#
# Время обучения: 195 с. (изменение: -12.56%)
#
# Задание 3:
#
# Точность на тестовых данных: 0.4869 (изменение: -22.37%)
#
# Точность:
#
# на обучении: 0.38 (изменение: -41.54%)
#
# на валидации: 0.48 (изменение: -20.00%)
#
# Ошибка:
#
# на обучении: 1.65 (изменение: +65.00%)
#
# на валидации: 1.45 (изменение: +31.82%)
#
# Время обучения: 235 с. (изменение: +20.51%)
#
# Задание 4:
#
# Средняя точность: 0.4465 (изменение: -8.30%)
#
# Время обучения: 553 с. (изменение: +135.32%)
#
# Задание 5:
#
# Средняя точность: 0.2467 (изменение: -44.76%)
#
# Время обучения: 590 с. (изменение: +6.69%)
#
# Лучшее/Худшее:
#
# Лучшая точность: 0.85 на обучении (Задание 1).
#
# Худшая точность: 0.2467 (Задание 5).
#
# Максимальное время обучения: 590 с. (Задание 5).
